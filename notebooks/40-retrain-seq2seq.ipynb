# %% [markdown]
# Retrain seq2seq model, using samples where
# - CER > 0 (to avoid learning to predict exactly the same thing)
# - ground-truth can be realigned with original OCR transcription (not a case of OCR failure, to avoid training on noisy data) => this is easy to check in our dataset thanks to the "has_valid_ner_xml" field which indicates that we were able to reproject XML tags used to label Named Entities from clean, human-corrected text to OCR predictions.

# %% [markdown]
# ## Data source

# %%
from pathlib import Path

# %%
dataset_basedir = Path("/lrde/home2/jchazalo/datasets/french_trade_directories_19th_century/")

# %%
extracted_data = dataset_basedir / "labeled/31-all_entries_ner_align_pero.json"

human_annot_path = dataset_basedir / "labeled/10-all_entries_ocr_ner_human.json"

# %%
import pandas as pd

# %%
def json_file_to_df(path: str) -> pd.DataFrame:
    with open(path, "r") as json_file:
        return pd.read_json(json_file)


human_df = json_file_to_df(human_annot_path)
auto_df = json_file_to_df(extracted_data)

len(human_df), len(auto_df)
# Out:
# (8765, 8765)

# %%
current_path = !pwd
current_path = current_path[0] if len(current_path) > 0 else None
import sys
if current_path is not None and current_path not in sys.path:
    sys.path.insert(0, current_path)
sys.path
# Out:
# ['/work-ssd/jchazalo/postocr',
#  '/work-ssd/jchazalo/postocr/paper-ner-bench-das22-2.0.0-camera-ready/src/ocr',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/work-ssd/jchazalo/postocr/venv/lib/python3.10/site-packages']

# %%
sys.path
# Out:
# ['/work-ssd/jchazalo/postocr',
#  '/work-ssd/jchazalo/postocr/paper-ner-bench-das22-2.0.0-camera-ready/src/ocr',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/work-ssd/jchazalo/postocr/venv/lib/python3.10/site-packages']

# %%
#!pip install regex

# %%
from text_utils import xml_unescape

# %%
df = human_df.loc[:, ["book", "page", "text_ocr", "ner_xml"]]
df = df.rename(columns={"text_ocr": "Ground Truth", "ner_xml": "NER Ground Truth"})
df.loc[:, "Sample"] = auto_df.loc[:, "text_ocr"]
df.loc[:, "NER Sample"] = auto_df.loc[:, "ner_xml"]
df.loc[:, "has_valid_ner_xml"] = auto_df.loc[:, "has_valid_ner_xml"]
df.loc[:, "NER Ground Truth"] = df["NER Ground Truth"].apply(xml_unescape)
df
# Out:
#                                book  page  \
# 0                      Bottin1_1820   107
# 1                      Bottin1_1820   107
# 2                      Bottin1_1820   107
# 3                      Bottin1_1820   107
# 4                      Bottin1_1820   107
# ...                             ...   ...
# 8760  Notables_communaux_seine_1801   144
# 8761  Notables_communaux_seine_1801   144
# 8762  Notables_communaux_seine_1801   144
# 8763  Notables_communaux_seine_1801   144
# 8764  Notables_communaux_seine_1801   144
#
#                                            Ground Truth  \
# 0     Dufan et Clémendot, pharmaciens, r. de la\nCha...
# 1     Dufant (Victor), libraire, r. du Gros-Che-\nne...
# 2     Dufay, essayeur du commerce, place Dau-\nphine...
# 3     Dulay, chandronnier, r. du Pont- aux\nChoux, 1...
# 4     Dufay (V.e), grenetière, r. du Faub.-S.\nDenis...
# ...                                                 ...
# 8760                 Lamarche, géographe , rue du foin.
# 8761  Lamarck, membre de l'institut, quatrième munic...
# 8762           Lamare, notaire, rue du faubourg honoré.
# 8763                 Lamarre , carrier, rue mouffetard.
# 8764            Lamarre, clerc de notaire, rue égalité.
#
#                                        NER Ground Truth  \
# 0     <PER>Dufan et Clémendot</PER>, <ACT>pharmacien...
# 1     <PER>Dufant (Victor)</PER>, <ACT>libraire</ACT...
# 2     <PER>Dufay</PER>, <ACT>essayeur du commerce</A...
# 3     <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...
# 4     <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...
# ...                                                 ...
# 8760  <PER>Lamarche</PER>, <ACT>géographe</ACT> , <L...
# 8761  <PER>Lamarck</PER>, <ACT>membre de l'institut<...
# 8762  <PER>Lamare</PER>, <ACT>notaire</ACT>, <LOC>ru...
# 8763  <PER>Lamarre</PER> , <ACT>carrier</ACT>, <LOC>...
# 8764  <PER>Lamarre</PER>, <ACT>clerc de notaire</ACT...
#
#                                                  Sample  \
# 0     Dufau et Clémendot, pharmaciens, r. de la\nChä...
# 1     ☞\n\nT\nDufant (Victor), libraire, r. du Gros-...
# 2     Dutay, essayeur du commerce, place Dau-\n\n-\n...
# 3     Dulay, chandronnier, r. du Pont- aux-\nChuux, ...
# 4     Dufay (V.e), grenetière, r. du Fauh.-S.\nDenis...
# ...                                                 ...
# 8760                 Lamarche, geographe , rue du foin.
# 8761  Lamarck, membre de l'institut, quatrieme munic...
# 8762          Lamare , notaire, rue du faubourg honore.
# 8763                  Lamarre, carrier, rue mouffetard.
# 8764            Lamarre, clerc de notaire, rue égalité.
#
#                                              NER Sample  has_valid_ner_xml
# 0     <PER>Dufau et Clémendot</PER>, <ACT>pharmacien...              False
# 1     ☞
#
# T
# <PER>Dufant (Victor)</PER>, <ACT>libraire...               True
# 2     <PER>Dutay</PER>, <ACT>essayeur du commerce</A...               True
# 3     <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...               True
# 4     <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...               True
# ...                                                 ...                ...
# 8760  <PER>Lamarche</PER>, <ACT>geographe</ACT> , <L...               True
# 8761  <PER>Lamarck</PER>, <ACT>membre de l&apos;inst...               True
# 8762  <PER>Lamare</PER> , <ACT>notaire</ACT>, <LOC>r...               True
# 8763  <PER>Lamarre</PER>, <ACT>carrier</ACT>, <LOC>r...               True
# 8764  <PER>Lamarre</PER>, <ACT>clerc de notaire</ACT...               True
#
# [8765 rows x 7 columns]

# %% [markdown]
# ## Filter out entries for which OCR transcription and target transcription cannot be aligned

# %%
df_valid = df.loc[df["has_valid_ner_xml"], :]
df_valid.head()
# Out:
#            book  page                                       Ground Truth  \
# 1  Bottin1_1820   107  Dufant (Victor), libraire, r. du Gros-Che-\nne...
# 2  Bottin1_1820   107  Dufay, essayeur du commerce, place Dau-\nphine...
# 3  Bottin1_1820   107  Dulay, chandronnier, r. du Pont- aux\nChoux, 1...
# 4  Bottin1_1820   107  Dufay (V.e), grenetière, r. du Faub.-S.\nDenis...
# 5  Bottin1_1820   107          Dufeu, charcutier, r. Montmartre, 89. 318
#
#                                     NER Ground Truth  \
# 1  <PER>Dufant (Victor)</PER>, <ACT>libraire</ACT...
# 2  <PER>Dufay</PER>, <ACT>essayeur du commerce</A...
# 3  <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...
# 4  <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...
# 5  <PER>Dufeu</PER>, <ACT>charcutier</ACT>, <LOC>...
#
#                                               Sample  \
# 1  ☞\n\nT\nDufant (Victor), libraire, r. du Gros-...
# 2  Dutay, essayeur du commerce, place Dau-\n\n-\n...
# 3  Dulay, chandronnier, r. du Pont- aux-\nChuux, ...
# 4  Dufay (V.e), grenetière, r. du Fauh.-S.\nDenis...
# 5     Y\n☞\nDnten,charentier, 1. Montmartre, 89. 318
#
#                                           NER Sample  has_valid_ner_xml
# 1  ☞
#
# T
# <PER>Dufant (Victor)</PER>, <ACT>libraire...               True
# 2  <PER>Dutay</PER>, <ACT>essayeur du commerce</A...               True
# 3  <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...               True
# 4  <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...               True
# 5  Y
# ☞
# <PER>Dnten</PER>,<ACT>charentier</ACT>, <L...               True

# %% [markdown]
# ## Keep only entries with errors
# With our dataset, this represents roughly half of the entries.
#
# Our goal here is to select appropriate samples to learn a character-level seq2seq model, avoiding the risk of learning to predict the same sequence as the input.

# %%
#!pip install evaluate jiwer cer

# %%
import evaluate
cer = evaluate.load("cer")
# Out:
# Downloading builder script:   0%|          | 0.00/5.60k [00:00<?, ?B/s]

# %%
import isri_tools

# %%
df_valid.iloc[0]["Ground Truth"], df_valid.iloc[0]["Sample"]
# Out:
# ('Dufant (Victor), libraire, r. du Gros-Che-\nnet, 2. 392',
#  '☞\n\nT\nDufant (Victor), libraire, r. du Gros-Che-\nnet. 2.\nJO')

# %%
stats0 = isri_tools.compute_accurary_stats(df_valid.iloc[0]["Ground Truth"], df_valid.iloc[0]["Sample"])
stats0
# Out:
# UNLV-ISRI OCR Accuracy Report Version 5.1
# -----------------------------------------
#       54   Characters
#       10   Errors
#    81.48%  Accuracy
#
#        0   Reject Characters
#        0   Suspect Markers
#        0   False Marks
#     0.00%  Characters Marked
#    81.48%  Accuracy After Correction
#
#      Ins    Subst      Del   Errors
#        0        0        0        0   Marked
#        1        4        5       10   Unmarked
#        1        4        5       10   Total
#
#    Count   Missed   %Right
#        8        1    87.50   ASCII Spacing Characters
#        9        1    88.89   ASCII Special Symbols
#        4        3    25.00   ASCII Digits
#        4        0   100.00   ASCII Uppercase Letters
#       29        0   100.00   ASCII Lowercase Letters
#       54        5    90.74   Total
#
#   Errors   Marked   Correct-Generated
#        5        0   {}-{<261E><\n><\n>T<\n>}
#        4        0   { 392}-{<\n>JO}
#        1        0   {,}-{.}
#
#    Count   Missed   %Right
#        1        0   100.00   {<\n>}
#        7        1    85.71   { }
#        1        0   100.00   {(}
#        1        0   100.00   {)}
#        3        1    66.67   {,}
#        2        0   100.00   {-}
#        2        0   100.00   {.}
#        2        1    50.00   {2}
#        1        1     0.00   {3}
#        1        1     0.00   {9}
#        1        0   100.00   {C}
#        1        0   100.00   {D}
#        1        0   100.00   {G}
#        1        0   100.00   {V}
#        2        0   100.00   {a}
#        1        0   100.00   {b}
#        1        0   100.00   {c}
#        1        0   100.00   {d}
#        3        0   100.00   {e}
#        1        0   100.00   {f}
#        1        0   100.00   {h}
#        3        0   100.00   {i}
#        1        0   100.00   {l}
#        2        0   100.00   {n}
#        2        0   100.00   {o}
#        5        0   100.00   {r}
#        1        0   100.00   {s}
#        3        0   100.00   {t}
#        2        0   100.00   {u}

# %%
stats0.characters, stats0.errors, stats0.false_marks, stats0.reject_characters, stats0.suspect_markers
# Out:
# (54, 10, 0, 0, 0)

# %% [markdown]
# We are missing ins/sub/del measures here!

# %%
stats1 = cer.compute(references=[df_valid.iloc[0]["Ground Truth"]], predictions=[df_valid.iloc[0]["Sample"]])
stats1
# Out:
# 0.16666666666666666

# %% [markdown]
# Same here :(

# %% [markdown]
# So, either I add some bindings in the modified ISRI tools, or I parse the output…
#
# Parsing will be super slow, I fixed our custom ISRI module instead.

# %%
lines = stats0.__repr__().split("\n")
lines[15]
# Out:
# '       1        4        5       10   Total'

# %%
stats0.total_ops
# Out:
# insertions: 1, substitutions: 4, deletions: 5

# %%
stats0.total_ops.insertions, stats0.total_ops.substitutions, stats0.total_ops.deletions, stats0.total_ops.errors
# Out:
# (1, 4, 5, 10)

# %% [markdown]
# We need to understand how substitutions are counted to be correct, and check it complies with the definition at <https://huggingface.co/spaces/evaluate-metric/cer>:
# $$
# CER = (S + D + I) / N = (S + D + I) / (S + D + C)
# $$
# where
#
# S is the number of substitutions, D is the number of deletions, I is the number of insertions, C is the number of correct characters, N is the number of characters in the reference (N=S+D+C).

# %%
stats2 = isri_tools.compute_accurary_stats("abbbbc", "addddc")
stats2.total_ops
# Out:
# insertions: 0, substitutions: 4, deletions: 0

# %%
stats2 = isri_tools.compute_accurary_stats("aaaacccc", "aaaaccccdddd")
stats2.total_ops
# Out:
# insertions: 0, substitutions: 0, deletions: 4

# %% [markdown]
# This seems correct, let's move on…

# %%
cer_all = cer.compute(references=list(df_valid["Ground Truth"]), predictions=list(df_valid["Sample"]))
cer_all
# Out:
# 0.032892845459141694

# %% [markdown]
# We cannot get enough details from the CER metric in the "evaluate" package. We need to define a custom evaluation function.

# %%
stats2.errors, stats2.characters
# Out:
# (4, 8)

# %%
def local_cer(ref: str, pred: str) -> float:
    stats = isri_tools.compute_accurary_stats(ref, pred)
    return stats.errors / stats.characters

# %%
# custom version
local_cer("aaaacccc", "aaaaccccdddd")
# Out:
# 0.5

# %%
# reference implementation
cer.compute(references=["aaaacccc"], predictions=["aaaaccccdddd"])
# Out:
# 0.5

# %%
def local_stats(ref: str, pred: str) -> tuple[int, int, int, int, int]:
    """Compute character-level stats

    Args:
        ref (str): Reference (target) string
        pred (str): Predicted (automatically transcripted) string

    Returns:
        tuple[int, int, int, int, int]: (ref len, total errors, insertions, substitutions, deletions)
    """
    stats = isri_tools.compute_accurary_stats(ref, pred)
    return stats.characters, stats.errors, stats.total_ops.insertions, stats.total_ops.substitutions, stats.total_ops.deletions

# %%
# Augment the dataframe with useful columns
df_valid.loc[:, ('ref_len', 'errors', 'insertions', 'substitutions', 'deletions')] = df_valid.apply(
        lambda line: pd.Series(
            local_stats(ref=line["Ground Truth"], pred=line["Sample"]),
            index=['ref_len', 'errors', 'insertions', 'substitutions', 'deletions']), 
        axis=1,
        result_type='expand')
df_valid.head()
# Out:
# /work-ssd/jchazalo/postocr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1884: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)
#            book  page                                       Ground Truth  \
# 1  Bottin1_1820   107  Dufant (Victor), libraire, r. du Gros-Che-\nne...
# 2  Bottin1_1820   107  Dufay, essayeur du commerce, place Dau-\nphine...
# 3  Bottin1_1820   107  Dulay, chandronnier, r. du Pont- aux\nChoux, 1...
# 4  Bottin1_1820   107  Dufay (V.e), grenetière, r. du Faub.-S.\nDenis...
# 5  Bottin1_1820   107          Dufeu, charcutier, r. Montmartre, 89. 318
#
#                                     NER Ground Truth  \
# 1  <PER>Dufant (Victor)</PER>, <ACT>libraire</ACT...
# 2  <PER>Dufay</PER>, <ACT>essayeur du commerce</A...
# 3  <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...
# 4  <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...
# 5  <PER>Dufeu</PER>, <ACT>charcutier</ACT>, <LOC>...
#
#                                               Sample  \
# 1  ☞\n\nT\nDufant (Victor), libraire, r. du Gros-...
# 2  Dutay, essayeur du commerce, place Dau-\n\n-\n...
# 3  Dulay, chandronnier, r. du Pont- aux-\nChuux, ...
# 4  Dufay (V.e), grenetière, r. du Fauh.-S.\nDenis...
# 5     Y\n☞\nDnten,charentier, 1. Montmartre, 89. 318
#
#                                           NER Sample  has_valid_ner_xml  \
# 1  ☞
#
# T
# <PER>Dufant (Victor)</PER>, <ACT>libraire...               True
# 2  <PER>Dutay</PER>, <ACT>essayeur du commerce</A...               True
# 3  <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...               True
# 4  <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...               True
# 5  Y
# ☞
# <PER>Dnten</PER>,<ACT>charentier</ACT>, <L...               True
#
#    ref_len  errors  insertions  substitutions  deletions
# 1       54      10           1              4          5
# 2       61      18           8              7          3
# 3       51       6           1              4          1
# 4       54       2           0              2          0
# 5       41      11           1              6          4

# %%
df_valid.loc[:, ("CER",)] = df_valid["errors"] / df_valid["ref_len"]
df_valid.head()
# Out:
# /work-ssd/jchazalo/postocr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#            book  page                                       Ground Truth  \
# 1  Bottin1_1820   107  Dufant (Victor), libraire, r. du Gros-Che-\nne...
# 2  Bottin1_1820   107  Dufay, essayeur du commerce, place Dau-\nphine...
# 3  Bottin1_1820   107  Dulay, chandronnier, r. du Pont- aux\nChoux, 1...
# 4  Bottin1_1820   107  Dufay (V.e), grenetière, r. du Faub.-S.\nDenis...
# 5  Bottin1_1820   107          Dufeu, charcutier, r. Montmartre, 89. 318
#
#                                     NER Ground Truth  \
# 1  <PER>Dufant (Victor)</PER>, <ACT>libraire</ACT...
# 2  <PER>Dufay</PER>, <ACT>essayeur du commerce</A...
# 3  <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...
# 4  <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...
# 5  <PER>Dufeu</PER>, <ACT>charcutier</ACT>, <LOC>...
#
#                                               Sample  \
# 1  ☞\n\nT\nDufant (Victor), libraire, r. du Gros-...
# 2  Dutay, essayeur du commerce, place Dau-\n\n-\n...
# 3  Dulay, chandronnier, r. du Pont- aux-\nChuux, ...
# 4  Dufay (V.e), grenetière, r. du Fauh.-S.\nDenis...
# 5     Y\n☞\nDnten,charentier, 1. Montmartre, 89. 318
#
#                                           NER Sample  has_valid_ner_xml  \
# 1  ☞
#
# T
# <PER>Dufant (Victor)</PER>, <ACT>libraire...               True
# 2  <PER>Dutay</PER>, <ACT>essayeur du commerce</A...               True
# 3  <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...               True
# 4  <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...               True
# 5  Y
# ☞
# <PER>Dnten</PER>,<ACT>charentier</ACT>, <L...               True
#
#    ref_len  errors  insertions  substitutions  deletions       CER
# 1       54      10           1              4          5  0.185185
# 2       61      18           8              7          3  0.295082
# 3       51       6           1              4          1  0.117647
# 4       54       2           0              2          0  0.037037
# 5       41      11           1              6          4  0.268293

# %%
df_recoverable_errors = df_valid[df_valid["errors"] > 0]
df_recoverable_errors
# Out:
#                                book  page  \
# 1                      Bottin1_1820   107
# 2                      Bottin1_1820   107
# 3                      Bottin1_1820   107
# 4                      Bottin1_1820   107
# 5                      Bottin1_1820   107
# ...                             ...   ...
# 8759  Notables_communaux_seine_1801   144
# 8760  Notables_communaux_seine_1801   144
# 8761  Notables_communaux_seine_1801   144
# 8762  Notables_communaux_seine_1801   144
# 8763  Notables_communaux_seine_1801   144
#
#                                            Ground Truth  \
# 1     Dufant (Victor), libraire, r. du Gros-Che-\nne...
# 2     Dufay, essayeur du commerce, place Dau-\nphine...
# 3     Dulay, chandronnier, r. du Pont- aux\nChoux, 1...
# 4     Dufay (V.e), grenetière, r. du Faub.-S.\nDenis...
# 5             Dufeu, charcutier, r. Montmartre, 89. 318
# ...                                                 ...
# 8759            Lamarche , marchand de vin, rue lazare.
# 8760                 Lamarche, géographe , rue du foin.
# 8761  Lamarck, membre de l'institut, quatrième munic...
# 8762           Lamare, notaire, rue du faubourg honoré.
# 8763                 Lamarre , carrier, rue mouffetard.
#
#                                        NER Ground Truth  \
# 1     <PER>Dufant (Victor)</PER>, <ACT>libraire</ACT...
# 2     <PER>Dufay</PER>, <ACT>essayeur du commerce</A...
# 3     <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...
# 4     <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...
# 5     <PER>Dufeu</PER>, <ACT>charcutier</ACT>, <LOC>...
# ...                                                 ...
# 8759  <PER>Lamarche</PER> , <ACT>marchand de vin</AC...
# 8760  <PER>Lamarche</PER>, <ACT>géographe</ACT> , <L...
# 8761  <PER>Lamarck</PER>, <ACT>membre de l'institut<...
# 8762  <PER>Lamare</PER>, <ACT>notaire</ACT>, <LOC>ru...
# 8763  <PER>Lamarre</PER> , <ACT>carrier</ACT>, <LOC>...
#
#                                                  Sample  \
# 1     ☞\n\nT\nDufant (Victor), libraire, r. du Gros-...
# 2     Dutay, essayeur du commerce, place Dau-\n\n-\n...
# 3     Dulay, chandronnier, r. du Pont- aux-\nChuux, ...
# 4     Dufay (V.e), grenetière, r. du Fauh.-S.\nDenis...
# 5        Y\n☞\nDnten,charentier, 1. Montmartre, 89. 318
# ...                                                 ...
# 8759           Lamarche , marchand de vin , rue lazare.
# 8760                 Lamarche, geographe , rue du foin.
# 8761  Lamarck, membre de l'institut, quatrieme munic...
# 8762          Lamare , notaire, rue du faubourg honore.
# 8763                  Lamarre, carrier, rue mouffetard.
#
#                                              NER Sample  has_valid_ner_xml  \
# 1     ☞
#
# T
# <PER>Dufant (Victor)</PER>, <ACT>libraire...               True
# 2     <PER>Dutay</PER>, <ACT>essayeur du commerce</A...               True
# 3     <PER>Dulay</PER>, <ACT>chandronnier</ACT>, <LO...               True
# 4     <PER>Dufay (V.e)</PER>, <ACT>grenetière</ACT>,...               True
# 5     Y
# ☞
# <PER>Dnten</PER>,<ACT>charentier</ACT>, <L...               True
# ...                                                 ...                ...
# 8759  <PER>Lamarche</PER> , <ACT>marchand de vin</AC...               True
# 8760  <PER>Lamarche</PER>, <ACT>geographe</ACT> , <L...               True
# 8761  <PER>Lamarck</PER>, <ACT>membre de l&apos;inst...               True
# 8762  <PER>Lamare</PER> , <ACT>notaire</ACT>, <LOC>r...               True
# 8763  <PER>Lamarre</PER>, <ACT>carrier</ACT>, <LOC>r...               True
#
#       ref_len  errors  insertions  substitutions  deletions       CER
# 1          54      10           1              4          5  0.185185
# 2          61      18           8              7          3  0.295082
# 3          51       6           1              4          1  0.117647
# 4          54       2           0              2          0  0.037037
# 5          41      11           1              6          4  0.268293
# ...       ...     ...         ...            ...        ...       ...
# 8759       39       1           0              0          1  0.025641
# 8760       34       1           0              1          0  0.029412
# 8761       54       2           0              2          0  0.037037
# 8762       40       2           0              1          1  0.050000
# 8763       34       1           1              0          0  0.029412
#
# [4681 rows x 13 columns]

# %%
print("all entries:", len(df))
print("-"*20)
print("\tentries with unrecoverable errors", len(df)-len(df_valid))
print("\tentries with valid alignment OCR pred ↔ target text", len(df_valid))
print("-"*20)
print("\t\tentries with recoverable errors", len(df_recoverable_errors))
print("\t\tentries without errors", len(df_valid)-len(df_recoverable_errors))
# Out:
# all entries: 8765
# --------------------
# 	entries with unrecoverable errors 373
# 	entries with valid alignment OCR pred ↔ target text 8392
# --------------------
# 		entries with recoverable errors 4681
# 		entries without errors 3711

# %% [markdown]
# # Split train test

# %%
#!pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
SEED = 0

# %%
train_df, test_df = train_test_split(df_recoverable_errors, test_size=0.1, shuffle=True, random_state=SEED)
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)
train_df.shape, test_df.shape
# Out:
# ((4212, 13), (469, 13))

# %% [markdown]
# # Launch the training!

# %%
from src.NMT_corrector import NMTCorrector

# %%
s2smdl = NMTCorrector()

# %%
# %%time
s2smdl.fit(X=train_df["Sample"], y=train_df["Ground Truth"])
# Out:
# Corpus train's weight should be given. We default it to 1 for you.
# [2023-05-29 18:25:53,813 INFO] Counter vocab from 10000 samples.
# [2023-05-29 18:25:53,813 INFO] Build vocab on 10000 transformed examples/corpus.
# [2023-05-29 18:25:53,972 INFO] Counters src:128
# [2023-05-29 18:25:53,972 INFO] Counters tgt:112
# [2023-05-29 18:25:56,023 WARNING] You have a CUDA device, should run with -gpu_ranks
# [2023-05-29 18:25:56,025 INFO] Missing transforms field for train data, set to default: [].
# [2023-05-29 18:25:56,025 WARNING] Corpus train's weight should be given. We default it to 1 for you.
# [2023-05-29 18:25:56,025 INFO] Missing transforms field for valid data, set to default: [].
# [2023-05-29 18:25:56,025 INFO] Parsed 2 corpora from -data.
# [2023-05-29 18:25:56,026 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-05-29 18:25:56,027 INFO] Building model...
# [2023-05-29 18:25:56,200 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(136, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (rnn): LSTM(500, 500, num_layers=2, batch_first=True, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(120, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (dropout): Dropout(p=0.3, inplace=False)
#     (rnn): StackedLSTM(
#       (dropout): Dropout(p=0.3, inplace=False)
#       (layers): ModuleList(
#         (0): LSTMCell(1000, 500)
#         (1): LSTMCell(500, 500)
#       )
#     )
#     (attn): GlobalAttention(
#       (linear_in): Linear(in_features=500, out_features=500, bias=False)
#       (linear_out): Linear(in_features=1000, out_features=500, bias=False)
#     )
#   )
#   (generator): Linear(in_features=500, out_features=120, bias=True)
# )
# [2023-05-29 18:25:56,200 INFO] encoder: 4076000
# [2023-05-29 18:25:56,200 INFO] decoder: 5878120
# [2023-05-29 18:25:56,200 INFO] * number of parameters: 9954120
# [2023-05-29 18:25:56,200 INFO]  * src vocab size = 136
# [2023-05-29 18:25:56,200 INFO]  * tgt vocab size = 120
# [2023-05-29 18:25:56,202 INFO] Weighted corpora loaded so far:
# 			* train: 1
# [2023-05-29 18:25:56,202 INFO] Starting training on CPU, could be very slow
# [2023-05-29 18:25:56,202 INFO] Start training loop and validate every 2001 steps...
# [2023-05-29 18:25:56,202 INFO] Scoring with: TransformPipe()
# [2023-05-29 18:25:56,244 INFO] Weighted corpora loaded so far:
# 			* train: 2
# [2023-05-29 18:25:56,285 INFO] Weighted corpora loaded so far:
# 			* train: 3
# [2023-05-29 18:25:56,328 INFO] Weighted corpora loaded so far:
# 			* train: 4
# [2023-05-29 18:25:56,453 INFO] Weighted corpora loaded so far:
# 			* train: 5
# [2023-05-29 18:25:56,497 INFO] Weighted corpora loaded so far:
# 			* train: 6
# [2023-05-29 18:25:56,542 INFO] Weighted corpora loaded so far:
# 			* train: 7
# [2023-05-29 18:25:56,726 INFO] Weighted corpora loaded so far:
# 			* train: 8
# [2023-05-29 18:25:56,771 INFO] Weighted corpora loaded so far:
# 			* train: 9
# [2023-05-29 18:25:56,817 INFO] Weighted corpora loaded so far:
# 			* train: 10
# [2023-05-29 18:25:56,859 INFO] Weighted corpora loaded so far:
# 			* train: 11
# [2023-05-29 18:25:57,027 INFO] Weighted corpora loaded so far:
# 			* train: 12
# [2023-05-29 18:25:57,071 INFO] Weighted corpora loaded so far:
# 			* train: 13
# [2023-05-29 18:25:57,113 INFO] Weighted corpora loaded so far:
# 			* train: 14
# [2023-05-29 18:25:57,156 INFO] Weighted corpora loaded so far:
# 			* train: 15
# [2023-05-29 18:25:57,357 INFO] Weighted corpora loaded so far:
# 			* train: 16
# [2023-05-29 18:25:57,399 INFO] Weighted corpora loaded so far:
# 			* train: 17
# [2023-05-29 18:25:57,447 INFO] Weighted corpora loaded so far:
# 			* train: 18
# [2023-05-29 18:25:57,489 INFO] Weighted corpora loaded so far:
# 			* train: 19
# [2023-05-29 18:25:57,532 INFO] Weighted corpora loaded so far:
# 			* train: 20
# [2023-05-29 18:25:57,575 INFO] Weighted corpora loaded so far:
# 			* train: 21
# [2023-05-29 18:25:57,813 INFO] Weighted corpora loaded so far:
# 			* train: 22
# [2023-05-29 18:25:57,855 INFO] Weighted corpora loaded so far:
# 			* train: 23
# [2023-05-29 18:25:57,898 INFO] Weighted corpora loaded so far:
# 			* train: 24
# [2023-05-29 18:25:57,941 INFO] Weighted corpora loaded so far:
# 			* train: 25
# [2023-05-29 18:25:57,984 INFO] Weighted corpora loaded so far:
# 			* train: 26
# [2023-05-29 18:25:58,027 INFO] Weighted corpora loaded so far:
# 			* train: 27
# [2023-05-29 18:25:58,307 INFO] Weighted corpora loaded so far:
# 			* train: 28
# [2023-05-29 18:25:58,351 INFO] Weighted corpora loaded so far:
# 			* train: 29
# [2023-05-29 18:25:58,393 INFO] Weighted corpora loaded so far:
# 			* train: 30
# [2023-05-29 18:25:58,438 INFO] Weighted corpora loaded so far:
# 			* train: 31
# [2023-05-29 18:25:58,481 INFO] Weighted corpora loaded so far:
# 			* train: 32
# [2023-05-29 18:25:58,525 INFO] Weighted corpora loaded so far:
# 			* train: 33
# [2023-05-29 18:25:58,568 INFO] Weighted corpora loaded so far:
# 			* train: 34
# [2023-05-29 18:25:58,612 INFO] Weighted corpora loaded so far:
# 			* train: 35
# [2023-05-29 18:25:58,655 INFO] Weighted corpora loaded so far:
# 			* train: 36
# [2023-05-29 18:25:58,999 INFO] Weighted corpora loaded so far:
# 			* train: 37
# [2023-05-29 18:25:59,043 INFO] Weighted corpora loaded so far:
# 			* train: 38
# [2023-05-29 18:25:59,085 INFO] Weighted corpora loaded so far:
# 			* train: 39
# [2023-05-29 18:25:59,133 INFO] Weighted corpora loaded so far:
# 			* train: 40
# [2023-05-29 18:25:59,175 INFO] Weighted corpora loaded so far:
# 			* train: 41
# [2023-05-29 18:25:59,220 INFO] Weighted corpora loaded so far:
# 			* train: 42
# [2023-05-29 18:25:59,263 INFO] Weighted corpora loaded so far:
# 			* train: 43
# [2023-05-29 18:25:59,307 INFO] Weighted corpora loaded so far:
# 			* train: 44
# [2023-05-29 18:25:59,350 INFO] Weighted corpora loaded so far:
# 			* train: 45
# [2023-05-29 18:25:59,393 INFO] Weighted corpora loaded so far:
# 			* train: 46
# [2023-05-29 18:25:59,807 INFO] Weighted corpora loaded so far:
# 			* train: 47
# [2023-05-29 18:25:59,850 INFO] Weighted corpora loaded so far:
# 			* train: 48
# [2023-05-29 18:25:59,893 INFO] Weighted corpora loaded so far:
# 			* train: 49
# [2023-05-29 18:25:59,937 INFO] Weighted corpora loaded so far:
# 			* train: 50
# [2023-05-29 18:25:59,979 INFO] Weighted corpora loaded so far:
# 			* train: 51
# [2023-05-29 18:26:00,023 INFO] Weighted corpora loaded so far:
# 			* train: 52
# [2023-05-29 18:26:00,066 INFO] Weighted corpora loaded so far:
# 			* train: 53
# [2023-05-29 18:26:00,110 INFO] Weighted corpora loaded so far:
# 			* train: 54
# [2023-05-29 18:26:00,152 INFO] Weighted corpora loaded so far:
# 			* train: 55
# [2023-05-29 18:26:00,195 INFO] Weighted corpora loaded so far:
# 			* train: 56
# [2023-05-29 18:26:00,237 INFO] Weighted corpora loaded so far:
# 			* train: 57
# [2023-05-29 18:26:00,281 INFO] Weighted corpora loaded so far:
# 			* train: 58
# [2023-05-29 18:26:00,323 INFO] Weighted corpora loaded so far:
# 			* train: 59
# [2023-05-29 18:26:00,367 INFO] Weighted corpora loaded so far:
# 			* train: 60
# [2023-05-29 18:26:00,878 INFO] Weighted corpora loaded so far:
# 			* train: 61
# [2023-05-29 18:26:00,921 INFO] Weighted corpora loaded so far:
# 			* train: 62
# [2023-05-29 18:26:00,964 INFO] Weighted corpora loaded so far:
# 			* train: 63
# [2023-05-29 18:27:09,600 INFO] Step 50/ 2000; acc: 8.8; ppl:  85.4; xent: 4.4; lr: 0.50000; sents:    3200; bsz: 2628/2700/64; 1790/1840 tok/s;     73 sec;
# [2023-05-29 18:28:06,701 INFO] Step 100/ 2000; acc: 13.6; ppl:  36.4; xent: 3.6; lr: 0.50000; sents:    3200; bsz: 2661/2731/64; 2330/2392 tok/s;    130 sec;
# [2023-05-29 18:29:06,362 INFO] Step 150/ 2000; acc: 23.0; ppl:  18.1; xent: 2.9; lr: 0.50000; sents:    3200; bsz: 2626/2694/64; 2201/2258 tok/s;    190 sec;
# [2023-05-29 18:30:03,063 INFO] Step 200/ 2000; acc: 29.3; ppl:  12.9; xent: 2.6; lr: 0.50000; sents:    3200; bsz: 2685/2755/64; 2368/2429 tok/s;    247 sec;
# [2023-05-29 18:31:00,133 INFO] Step 250/ 2000; acc: 34.4; ppl:  10.4; xent: 2.3; lr: 0.50000; sents:    3200; bsz: 2661/2732/64; 2331/2394 tok/s;    304 sec;
# [2023-05-29 18:31:58,444 INFO] Step 300/ 2000; acc: 38.7; ppl:   8.6; xent: 2.1; lr: 0.50000; sents:    3200; bsz: 2593/2663/64; 2223/2284 tok/s;    362 sec;
# [2023-05-29 18:32:52,959 INFO] Step 350/ 2000; acc: 41.8; ppl:   7.6; xent: 2.0; lr: 0.50000; sents:    3200; bsz: 2586/2658/64; 2372/2438 tok/s;    417 sec;
# [2023-05-29 18:33:47,279 INFO] Step 400/ 2000; acc: 46.8; ppl:   6.3; xent: 1.8; lr: 0.50000; sents:    3200; bsz: 2474/2548/64; 2277/2346 tok/s;    471 sec;
# [2023-05-29 18:33:47,282 INFO] Saving checkpoint models/nmt/model/checkpoint_step_400.pt
# [2023-05-29 18:34:41,044 INFO] Step 450/ 2000; acc: 49.6; ppl:   5.8; xent: 1.8; lr: 0.50000; sents:    3200; bsz: 2538/2607/64; 2360/2425 tok/s;    525 sec;
# [2023-05-29 18:35:36,575 INFO] Step 500/ 2000; acc: 53.5; ppl:   5.0; xent: 1.6; lr: 0.50000; sents:    3200; bsz: 2648/2719/64; 2384/2448 tok/s;    580 sec;
# [2023-05-29 18:36:22,363 INFO] Step 550/ 2000; acc: 60.8; ppl:   3.9; xent: 1.4; lr: 0.50000; sents:    3200; bsz: 2449/2518/64; 2674/2750 tok/s;    626 sec;
# [2023-05-29 18:37:06,423 INFO] Step 600/ 2000; acc: 78.7; ppl:   2.2; xent: 0.8; lr: 0.50000; sents:    3200; bsz: 2579/2648/64; 2927/3005 tok/s;    670 sec;
# [2023-05-29 18:37:51,740 INFO] Step 650/ 2000; acc: 89.8; ppl:   1.5; xent: 0.4; lr: 0.50000; sents:    3200; bsz: 2636/2711/64; 2908/2992 tok/s;    716 sec;
# [2023-05-29 18:38:38,394 INFO] Step 700/ 2000; acc: 93.6; ppl:   1.3; xent: 0.3; lr: 0.50000; sents:    3200; bsz: 2577/2647/64; 2762/2837 tok/s;    762 sec;
# [2023-05-29 18:39:41,028 INFO] Step 750/ 2000; acc: 94.5; ppl:   1.3; xent: 0.2; lr: 0.50000; sents:    3200; bsz: 2769/2840/64; 2211/2267 tok/s;    825 sec;
# [2023-05-29 18:42:09,793 INFO] Step 800/ 2000; acc: 92.9; ppl:   1.4; xent: 0.3; lr: 0.50000; sents:    3200; bsz: 2960/3032/64; 995/1019 tok/s;    974 sec;
# [2023-05-29 18:42:09,795 INFO] Saving checkpoint models/nmt/model/checkpoint_step_800.pt
# [2023-05-29 18:43:06,965 INFO] Step 850/ 2000; acc: 95.4; ppl:   1.2; xent: 0.2; lr: 0.50000; sents:    3200; bsz: 2680/2752/64; 2344/2406 tok/s;   1031 sec;
# [2023-05-29 18:44:08,117 INFO] Step 900/ 2000; acc: 96.0; ppl:   1.2; xent: 0.2; lr: 0.50000; sents:    3200; bsz: 2756/2825/64; 2254/2310 tok/s;   1092 sec;
# [2023-05-29 18:45:05,146 INFO] Step 950/ 2000; acc: 96.0; ppl:   1.2; xent: 0.2; lr: 0.50000; sents:    3200; bsz: 2609/2682/64; 2288/2351 tok/s;   1149 sec;
# [2023-05-29 18:46:01,239 INFO] Step 1000/ 2000; acc: 96.3; ppl:   1.2; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2535/2605/64; 2259/2322 tok/s;   1205 sec;
# [2023-05-29 18:47:00,602 INFO] Step 1050/ 2000; acc: 96.7; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2644/2713/64; 2227/2285 tok/s;   1264 sec;
# [2023-05-29 18:47:55,955 INFO] Step 1100/ 2000; acc: 96.6; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2561/2634/64; 2314/2379 tok/s;   1320 sec;
# [2023-05-29 18:48:54,081 INFO] Step 1150/ 2000; acc: 96.7; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2637/2711/64; 2269/2332 tok/s;   1378 sec;
# [2023-05-29 18:49:42,945 INFO] Step 1200/ 2000; acc: 96.9; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2571/2646/64; 2631/2707 tok/s;   1427 sec;
# [2023-05-29 18:49:42,947 INFO] Saving checkpoint models/nmt/model/checkpoint_step_1200.pt
# [2023-05-29 18:50:25,842 INFO] Step 1250/ 2000; acc: 97.0; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2625/2695/64; 3060/3141 tok/s;   1470 sec;
# [2023-05-29 18:51:07,987 INFO] Step 1300/ 2000; acc: 97.1; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2594/2664/64; 3078/3161 tok/s;   1512 sec;
# [2023-05-29 18:51:56,929 INFO] Step 1350/ 2000; acc: 97.1; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2588/2659/64; 2644/2716 tok/s;   1561 sec;
# [2023-05-29 18:52:54,063 INFO] Step 1400/ 2000; acc: 97.5; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2747/2821/64; 2404/2469 tok/s;   1618 sec;
# [2023-05-29 18:53:55,389 INFO] Step 1450/ 2000; acc: 97.5; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2727/2799/64; 2224/2282 tok/s;   1679 sec;
# [2023-05-29 18:54:57,113 INFO] Step 1500/ 2000; acc: 97.5; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2707/2779/64; 2193/2251 tok/s;   1741 sec;
# [2023-05-29 18:55:55,749 INFO] Step 1550/ 2000; acc: 97.8; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2636/2705/64; 2248/2306 tok/s;   1800 sec;
# [2023-05-29 18:56:53,015 INFO] Step 1600/ 2000; acc: 97.6; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2529/2599/64; 2209/2270 tok/s;   1857 sec;
# [2023-05-29 18:56:53,017 INFO] Saving checkpoint models/nmt/model/checkpoint_step_1600.pt
# [2023-05-29 18:57:49,273 INFO] Step 1650/ 2000; acc: 98.0; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2521/2596/64; 2240/2307 tok/s;   1913 sec;
# [2023-05-29 18:58:46,690 INFO] Step 1700/ 2000; acc: 97.8; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2561/2632/64; 2230/2292 tok/s;   1970 sec;
# [2023-05-29 18:59:45,226 INFO] Step 1750/ 2000; acc: 98.1; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2560/2633/64; 2187/2249 tok/s;   2029 sec;
# [2023-05-29 19:00:45,032 INFO] Step 1800/ 2000; acc: 97.9; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2637/2708/64; 2205/2264 tok/s;   2089 sec;
# [2023-05-29 19:01:43,090 INFO] Step 1850/ 2000; acc: 98.0; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2581/2652/64; 2223/2284 tok/s;   2147 sec;
# [2023-05-29 19:02:41,139 INFO] Step 1900/ 2000; acc: 98.2; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2587/2656/64; 2228/2288 tok/s;   2205 sec;
# [2023-05-29 19:03:38,394 INFO] Step 1950/ 2000; acc: 98.4; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2519/2588/64; 2200/2260 tok/s;   2262 sec;
# [2023-05-29 19:04:41,828 INFO] Step 2000/ 2000; acc: 97.7; ppl:   1.1; xent: 0.1; lr: 0.50000; sents:    3200; bsz: 2730/2802/64; 2152/2208 tok/s;   2326 sec;
# [2023-05-29 19:04:41,829 INFO] Saving checkpoint models/nmt/model/checkpoint_step_2000.pt
# CPU times: user 423 ms, sys: 123 ms, total: 546 ms
# Wall time: 38min 51s

# %%
# %%time
s2smdl.score(X=train_df["Sample"], y=train_df["Ground Truth"])
# Out:
# [2023-05-29 19:08:05,549 INFO] PRED SCORE: -0.0160, PRED PPL: 1.02 NB SENTENCES: 4212
# CPU times: user 719 ms, sys: 9.24 ms, total: 728 ms
# Wall time: 3min 23s
# 0.17289230437007375

# %%
# %%time
s2smdl.score(X=test_df["Sample"], y=test_df["Ground Truth"])
# Out:
# [2023-05-29 19:08:32,030 INFO] PRED SCORE: -0.0227, PRED PPL: 1.02 NB SENTENCES: 469
# CPU times: user 249 ms, sys: 20.3 ms, total: 269 ms
# Wall time: 26.1 s
# 0.1779204213471588

# %%
# %%time
pred_test = s2smdl.predict(test_df["Sample"])
pred_test
# Out:
# [2023-05-29 21:37:38,472 INFO] PRED SCORE: -0.0227, PRED PPL: 1.02 NB SENTENCES: 469
# CPU times: user 24.5 ms, sys: 1.58 ms, total: 26.1 ms
# Wall time: 20.9 s
# 0                                                                                                                                                                                                              Collugyod Marshall, peausster, Mon-\ntorgueil, 82.
# 1                                                                                                                                                                                                                            Rennit , et Pignard, RiN. Eganterde.
# 2                                                                                                                                                                                                 Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                                                                                                                                                                                                            Audinot (Mlle ), R. Pino , 12.—M. B.
# 4                                                                                                                                                                                       Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.
#                                                                                                                                   ...
# 464                                                                                                                                                                                                                                Burty, nick. p r. Meslayi, 92.
# 465                                                                                                                                                                      Dufour, march. de vins, r-des Boucheries-\nS.-Germain. 67.\nB.-Germain. 67.\nB.-Germain.
# 466                                                                                                                                                                                                                                          Bacot, Laffitte, 42.
# 467                                                                                                                                                                                                                        Caudecoste (de), avocat, Provence, 24.
# 468    Association du Sablier , marbre, trailleurs de pierre réunis.\npour les monuments funèbres,\npour les monuments funèbres,\npour les monuments funèbres,\npour les monuments funèbres,\npour les monuments funèbres,\npour les monuments funèbres,\npour le
# Length: 469, dtype: object

# %%
results = test_df.copy()
results.loc[:, ("Predictions",)] = pred_test
results.head()
# Out:
#                           book  page  \
# 0          Cambon_almgene_1841   141
# 1  Duverneuil_et_La_Tynna_1806   147
# 2            DidotBottin_1860a   280
# 3  Duverneuil_et_La_Tynna_1805   292
# 4                  Didot_1851a   226
#
#                                                                   Ground Truth  \
# 0                         Collingwood Marshall, peaussier, Mon-\ntorgueil, 82.
# 1                                        Benoit et Pignard, R. N. Egalité, 64.
# 2              Grandemange, fab. de visières et brides, Si-\nmon-le-Franc, 13.
# 3                                        Audinot (Mlle ), R. Pinon, 12.— M. B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt; 219. *
#
#                                                                                                                     NER Ground Truth  \
# 0                         <PER>Collingwood Marshall</PER>, <ACT>peaussier</ACT>, <LOC>Mon-\ntorgueil</LOC>, <CARDINAL>82</CARDINAL>.
# 1                                                   <PER>Benoit et Pignard</PER>, <LOC>R. N. Egalité</LOC>, <CARDINAL>64</CARDINAL>.
# 2              <PER>Grandemange</PER>, <ACT>fab. de visières et brides</ACT>, <LOC>Si-\nmon-le-Franc</LOC>, <CARDINAL>13</CARDINAL>.
# 3                                        <PER>Audinot (Mlle )</PER>, <LOC>R. Pinon</LOC>, <CARDINAL>12</CARDINAL>.— <LOC>M. B</LOC>.
# 4  <PER>Gautier et Fortier</PER>, <ACT>fab. de produits chimiques</ACT>,<LOC>\nSt-Maur-Popincourt</LOC>; <CARDINAL>219</CARDINAL>. *
#
#                                                                       Sample  \
# 0                        Collugwood Marshall, peausster, Mon-\ntorgucil, 82.
# 1                                        Rennit "et Pignard, RiN. Eganterdí.
# 2            Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                       Audinot (Mlle ), R. Pinon, 12.—M, B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.
#
#                                                                                                                        NER Sample  \
# 0                        <PER>Collugwood Marshall</PER>, <ACT>peausster</ACT>, <LOC>Mon-
# torgucil</LOC>, <CARDINAL>82</CARDINAL>.
# 1                                             <PER>Rennit &quot;et Pignard</PER>, <LOC>RiN. Egante</LOC>rd<CARDINAL>í</CARDINAL>.
# 2            <PER>Grandemange</PER>, <ACT>fab. de visieres et brides</ACT>, <LOC>Si-
# mon-le-Franc</LOC>, <CARDINAL>13</CARDINAL>.
# 3                                      <PER>Audinot (Mlle )</PER>, <LOC>R. Pinon</LOC>, <CARDINAL>12</CARDINAL>.—<LOC>M, B</LOC>.
# 4  <PER>Gautier et Fortier</PER>, <ACT>fab. de produits chimiques</ACT>,<LOC>
# St-Maur-Popincourt</LOC>, <CARDINAL>219</CARDINAL>.
#
#    has_valid_ner_xml  ref_len  errors  insertions  substitutions  deletions  \
# 0               True       51       4           1              3          0
# 1               True       37      12           3              8          1
# 2               True       62       1           0              1          0
# 3               True       37       2           1              1          0
# 4               True       74       3           2              1          0
#
#         CER  \
# 0  0.078431
# 1  0.324324
# 2  0.016129
# 3  0.054054
# 4  0.040541
#
#                                                                  Predictions
# 0                         Collugyod Marshall, peausster, Mon-\ntorgueil, 82.
# 1                                       Rennit , et Pignard, RiN. Eganterde.
# 2            Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                       Audinot (Mlle ), R. Pino , 12.—M. B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.

# %% [markdown]
# ## Compute post-correction CER

# %%
results.loc[:, ("CER post corr",)] = results.apply(
        lambda line: local_cer(ref=line["Ground Truth"], pred=line["Predictions"]),
        axis=1)
results.head()
# Out:
#                           book  page  \
# 0          Cambon_almgene_1841   141
# 1  Duverneuil_et_La_Tynna_1806   147
# 2            DidotBottin_1860a   280
# 3  Duverneuil_et_La_Tynna_1805   292
# 4                  Didot_1851a   226
#
#                                                                   Ground Truth  \
# 0                         Collingwood Marshall, peaussier, Mon-\ntorgueil, 82.
# 1                                        Benoit et Pignard, R. N. Egalité, 64.
# 2              Grandemange, fab. de visières et brides, Si-\nmon-le-Franc, 13.
# 3                                        Audinot (Mlle ), R. Pinon, 12.— M. B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt; 219. *
#
#                                                                                                                     NER Ground Truth  \
# 0                         <PER>Collingwood Marshall</PER>, <ACT>peaussier</ACT>, <LOC>Mon-\ntorgueil</LOC>, <CARDINAL>82</CARDINAL>.
# 1                                                   <PER>Benoit et Pignard</PER>, <LOC>R. N. Egalité</LOC>, <CARDINAL>64</CARDINAL>.
# 2              <PER>Grandemange</PER>, <ACT>fab. de visières et brides</ACT>, <LOC>Si-\nmon-le-Franc</LOC>, <CARDINAL>13</CARDINAL>.
# 3                                        <PER>Audinot (Mlle )</PER>, <LOC>R. Pinon</LOC>, <CARDINAL>12</CARDINAL>.— <LOC>M. B</LOC>.
# 4  <PER>Gautier et Fortier</PER>, <ACT>fab. de produits chimiques</ACT>,<LOC>\nSt-Maur-Popincourt</LOC>; <CARDINAL>219</CARDINAL>. *
#
#                                                                       Sample  \
# 0                        Collugwood Marshall, peausster, Mon-\ntorgucil, 82.
# 1                                        Rennit "et Pignard, RiN. Eganterdí.
# 2            Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                       Audinot (Mlle ), R. Pinon, 12.—M, B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.
#
#                                                                                                                        NER Sample  \
# 0                        <PER>Collugwood Marshall</PER>, <ACT>peausster</ACT>, <LOC>Mon-
# torgucil</LOC>, <CARDINAL>82</CARDINAL>.
# 1                                             <PER>Rennit &quot;et Pignard</PER>, <LOC>RiN. Egante</LOC>rd<CARDINAL>í</CARDINAL>.
# 2            <PER>Grandemange</PER>, <ACT>fab. de visieres et brides</ACT>, <LOC>Si-
# mon-le-Franc</LOC>, <CARDINAL>13</CARDINAL>.
# 3                                      <PER>Audinot (Mlle )</PER>, <LOC>R. Pinon</LOC>, <CARDINAL>12</CARDINAL>.—<LOC>M, B</LOC>.
# 4  <PER>Gautier et Fortier</PER>, <ACT>fab. de produits chimiques</ACT>,<LOC>
# St-Maur-Popincourt</LOC>, <CARDINAL>219</CARDINAL>.
#
#    has_valid_ner_xml  ref_len  errors  insertions  substitutions  deletions  \
# 0               True       51       4           1              3          0
# 1               True       37      12           3              8          1
# 2               True       62       1           0              1          0
# 3               True       37       2           1              1          0
# 4               True       74       3           2              1          0
#
#         CER  \
# 0  0.078431
# 1  0.324324
# 2  0.016129
# 3  0.054054
# 4  0.040541
#
#                                                                  Predictions  \
# 0                         Collugyod Marshall, peausster, Mon-\ntorgueil, 82.
# 1                                       Rennit , et Pignard, RiN. Eganterde.
# 2            Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                       Audinot (Mlle ), R. Pino , 12.—M. B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.
#
#    CER post corr
# 0       0.098039
# 1       0.351351
# 2       0.016129
# 3       0.054054
# 4       0.040541

# %%
results.loc[:, ("is_improved_or_same",)] = results["CER post corr"] <= results["CER"]
results.loc[:, ("is_improved_strictly",)] = results["CER post corr"] < results["CER"]
results.head()
# Out:
#                           book  page  \
# 0          Cambon_almgene_1841   141
# 1  Duverneuil_et_La_Tynna_1806   147
# 2            DidotBottin_1860a   280
# 3  Duverneuil_et_La_Tynna_1805   292
# 4                  Didot_1851a   226
#
#                                                                   Ground Truth  \
# 0                         Collingwood Marshall, peaussier, Mon-\ntorgueil, 82.
# 1                                        Benoit et Pignard, R. N. Egalité, 64.
# 2              Grandemange, fab. de visières et brides, Si-\nmon-le-Franc, 13.
# 3                                        Audinot (Mlle ), R. Pinon, 12.— M. B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt; 219. *
#
#                                                                                                                     NER Ground Truth  \
# 0                         <PER>Collingwood Marshall</PER>, <ACT>peaussier</ACT>, <LOC>Mon-\ntorgueil</LOC>, <CARDINAL>82</CARDINAL>.
# 1                                                   <PER>Benoit et Pignard</PER>, <LOC>R. N. Egalité</LOC>, <CARDINAL>64</CARDINAL>.
# 2              <PER>Grandemange</PER>, <ACT>fab. de visières et brides</ACT>, <LOC>Si-\nmon-le-Franc</LOC>, <CARDINAL>13</CARDINAL>.
# 3                                        <PER>Audinot (Mlle )</PER>, <LOC>R. Pinon</LOC>, <CARDINAL>12</CARDINAL>.— <LOC>M. B</LOC>.
# 4  <PER>Gautier et Fortier</PER>, <ACT>fab. de produits chimiques</ACT>,<LOC>\nSt-Maur-Popincourt</LOC>; <CARDINAL>219</CARDINAL>. *
#
#                                                                       Sample  \
# 0                        Collugwood Marshall, peausster, Mon-\ntorgucil, 82.
# 1                                        Rennit "et Pignard, RiN. Eganterdí.
# 2            Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                       Audinot (Mlle ), R. Pinon, 12.—M, B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.
#
#                                                                                                                        NER Sample  \
# 0                        <PER>Collugwood Marshall</PER>, <ACT>peausster</ACT>, <LOC>Mon-
# torgucil</LOC>, <CARDINAL>82</CARDINAL>.
# 1                                             <PER>Rennit &quot;et Pignard</PER>, <LOC>RiN. Egante</LOC>rd<CARDINAL>í</CARDINAL>.
# 2            <PER>Grandemange</PER>, <ACT>fab. de visieres et brides</ACT>, <LOC>Si-
# mon-le-Franc</LOC>, <CARDINAL>13</CARDINAL>.
# 3                                      <PER>Audinot (Mlle )</PER>, <LOC>R. Pinon</LOC>, <CARDINAL>12</CARDINAL>.—<LOC>M, B</LOC>.
# 4  <PER>Gautier et Fortier</PER>, <ACT>fab. de produits chimiques</ACT>,<LOC>
# St-Maur-Popincourt</LOC>, <CARDINAL>219</CARDINAL>.
#
#    has_valid_ner_xml  ref_len  errors  insertions  substitutions  deletions  \
# 0               True       51       4           1              3          0
# 1               True       37      12           3              8          1
# 2               True       62       1           0              1          0
# 3               True       37       2           1              1          0
# 4               True       74       3           2              1          0
#
#         CER  \
# 0  0.078431
# 1  0.324324
# 2  0.016129
# 3  0.054054
# 4  0.040541
#
#                                                                  Predictions  \
# 0                         Collugyod Marshall, peausster, Mon-\ntorgueil, 82.
# 1                                       Rennit , et Pignard, RiN. Eganterde.
# 2            Grandemange, fab. de visieres et brides, Si-\nmon-le-Franc, 13.
# 3                                       Audinot (Mlle ), R. Pino , 12.—M. B.
# 4  Gautier et Fortier, fab. de produits chimiques,\nSt-Maur-Popincourt, 219.
#
#    CER post corr  is_improved_or_same  is_improved_strictly
# 0       0.098039                False                 False
# 1       0.351351                False                 False
# 2       0.016129                 True                 False
# 3       0.054054                 True                 False
# 4       0.040541                 True                 False

# %%
len(results), results.loc[:, ("has_valid_ner_xml", "is_improved_or_same", "is_improved_strictly")].sum(axis=0)
# Out:
# (469,
#  has_valid_ner_xml       469
#  is_improved_or_same     322
#  is_improved_strictly    196
#  dtype: int64)

# %%
print(f"Same:   {(322-196)/469*100:.2f}%")
print(f"Better: {(196)/469*100:.2f}%")
print(f"Worse:  {(469-322)/469*100:.2f}%")
# Out:
# Same:   26.87%
# Better: 41.79%
# Worse:  31.34%

# %%
results[results["is_improved_strictly"]].sample(10).loc[:,("Sample", "Predictions", "Ground Truth", "CER", "CER post corr")]
# Out:
#                                                                Sample  \
# 121                                     Borel, carrossier, Cadet,\n7.
# 244                               Lavarde, R. Batave, 400. Tuileries.
# 123                        Bridan\nA\nfab, le creux, r. du Puits.I\n—
# 443             Courty-Fontaine, cordons de montres, St-De-\nnIS.309.
# 389                        Legrand (Mile.), boulang. r. aux Ours. 30.
# 18                                       DUPRE, r. des Canneltes, 15.
# 422                          Collinct, chén. Ferme des Mathurins, 28.
# 218  Grandet i2, conseiller maître à la cour des\ncomptes, Ferme. 26.
# 135         Gachard et Comp.\n(fab.), R. du Faub. Denis, 36. Poisson.
# 147                 Carpentier, cloitre-Honoré, n. 15, - de la Halle.
#
#                                                          Predictions  \
# 121                                     Borel, carrossier, Cadet, 7.
# 244                             Lavarde , R. Batave, 400. Tuileries.
# 123                     Bridan (Ae), fab, le creux, r. du Puits. 19.
# 443            Courty-Fontaine, cordons de montres, St-De-\nnis, 38.
# 389                       Legrand (Mlle.), boulang. r. aux Ours. 30.
# 18                                      DUPRÉ, r. des Canneltes, 15.
# 422                         Collinet, chén. Ferme des Mathurins, 28.
# 218  Grandet , conseiller maçtre à la cour des\ncomptes, Ferme. 26.
# 135         Gachard et Comp. (fab.). R. du Faub. Denis, 36. Poisson.
# 147                Carpentier, cloître-Honoré, n. 15, - de la Halle.
#
#                                                         Ground Truth  \
# 121                                     Borel, carrossier, Cadet, 7.
# 244                             Lavarde , R. Batave, 400. Tuileries.
# 123                        Bridan A.. fab. le creux. r du Puits, 12.
# 443          Courty-Fontaine, cordons de montres, St- De-\nnis, 309.
# 389                      Legrand (Mlle.), boulang., r. aux Ours, 30.
# 18                                      DUPRÉ, r. des Cannettes, 15.
# 422                         Collinet, ébén. Ferme des Mathurins, 28.
# 218  Grandet , conseiller maître à la cour des\ncomptes, Ferme, 26.
# 135       Gachard et Comp. ( fab.). R. du Faub. Denis , 36. Poisson.
# 147                Carpentier, cloître-Honoré, n. 15, - de la Halle.
#
#           CER  CER post corr
# 121  0.035714       0.000000
# 244  0.027778       0.000000
# 123  0.292683       0.219512
# 443  0.092593       0.055556
# 389  0.069767       0.046512
# 18   0.071429       0.035714
# 422  0.075000       0.050000
# 218  0.048387       0.032258
# 135  0.068966       0.034483
# 147  0.020408       0.000000

# %% [markdown]
# # TODO
# - [ ] analyze for each kind of named entity
# - [ ] perform some simple space normalization before any correction? (no, avoid hand-written rules)
# - [ ] (later) self-supervised pre-training
# - [ ] check whether we need some early stopping

# %% [markdown]
# # Prepare train set for the verifier

# %%
# %%time
pred_train = s2smdl.predict(train_df["Sample"])
pred_train
# Out:
# [2023-05-29 22:28:19,429 INFO] PRED SCORE: -0.0160, PRED PPL: 1.02 NB SENTENCES: 4212
# CPU times: user 153 ms, sys: 36.1 ms, total: 189 ms
# Wall time: 2min 40s
# 0                                     Petit, nég. f. St Martin, 13.
# 1                        Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2                       Cave générale des hospices, Ne-N. -Dame, 2.
# 3                           Moreau (H.), avoc. cour imp., Alger, 9.
# 4               Laurent (J. A.) (miniature) , rue Nicaise, no. 487.
#                                    ...
# 4207                         Dufour fils, corroyeur, Châtillon, 14.
# 4208       Lépine (J.-B. ), architecte, Marais-Saint-Ger-\nmain. 3.
# 4209                          PAULMIR, r. de la Ferronnerie, 4. 472
# 4210                             Audouard, O. , médecin, Cadet, 6.
# 4211    Gauthier-la-Chapelle, avocat à la cour d'appel,\nOdeon, 31.
# Length: 4212, dtype: object

# %%
train_verif = train_df.copy()
train_verif.loc[:, ("Predictions",)] = pred_train
train_verif.head()
# Out:
#                      book  page  \
# 0     Cambon_almgene_1841   330
# 1            Bottin1_1827    37
# 2            Bottin1_1837    80
# 3       DidotBottin_1861a   424
# 4  Favre_et_Duchesne_1798   700
#
#                                           Ground Truth  \
# 0                        Petit, nég. f. St Martin, 13.
# 1           Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2          Cave générale des hospices, Ne-N. -Dame, 2.
# 3             Moreau (H. ), avoc. cour imp., Alger, 9.
# 4  Jaurent (J. A.) (miniature) , rue Nicaise, no. 487.
#
#                                                                                             NER Ground Truth  \
# 0                        <PER>Petit</PER>, <ACT>nég.</ACT> <LOC>f. St Martin</LOC>, <CARDINAL>13</CARDINAL>.
# 1           <PER>Balizeaux (Mad.)</PER>, <ACT>lingère</ACT>, <LOC>S.-Honuré</LOC>, <CARDINAL>169</CARDINAL>.
# 2                     <PER>Cave générale des hospices</PER>, <LOC>Ne-N. -Dame</LOC>, <CARDINAL>2</CARDINAL>.
# 3             <PER>Moreau (H. )</PER>, <ACT>avoc. cour imp.</ACT>, <LOC>Alger</LOC>, <CARDINAL>9</CARDINAL>.
# 4  <PER>Jaurent (J. A.)</PER> <ACT>(miniature)</ACT> , <LOC>rue Nicaise</LOC>, no. <CARDINAL>487</CARDINAL>.
#
#                                                  Sample  \
# 0                         Felit, neg. f. St Martin, 13.
# 1            Balizeaux (Mad.), lingère, S.-Honoré, 169.
# 2            Cave générale des hospices, Ne-N. Dame, 2.
# 3               Moreau (H.), avoc. cour imp., Alger, 9.
# 4  Laurent (J. A.) (miniature)\n, rue Nicaise, no. 487.
#
#                                                                                                   NER Sample  \
# 0                        <PER>Felit</PER>, <ACT>neg.</ACT> <LOC>f. St Martin</LOC>, <CARDINAL>13</CARDINAL>.
# 1           <PER>Balizeaux (Mad.)</PER>, <ACT>lingère</ACT>, <LOC>S.-Honoré</LOC>, <CARDINAL>169</CARDINAL>.
# 2                      <PER>Cave générale des hospices</PER>, <LOC>Ne-N. Dame</LOC>, <CARDINAL>2</CARDINAL>.
# 3              <PER>Moreau (H.)</PER>, <ACT>avoc. cour imp.</ACT>, <LOC>Alger</LOC>, <CARDINAL>9</CARDINAL>.
# 4  <PER>Laurent (J. A.)</PER> <ACT>(miniature)</ACT>
# , <LOC>rue Nicaise</LOC>, no. <CARDINAL>487</CARDINAL>.
#
#    has_valid_ner_xml  ref_len  errors  insertions  substitutions  deletions  \
# 0               True       29       3           0              3          0
# 1               True       42       1           0              1          0
# 2               True       43       1           1              0          0
# 3               True       40       1           1              0          0
# 4               True       51       2           0              2          0
#
#         CER                                          Predictions
# 0  0.103448                        Petit, nég. f. St Martin, 13.
# 1  0.023810           Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2  0.023256          Cave générale des hospices, Ne-N. -Dame, 2.
# 3  0.025000              Moreau (H.), avoc. cour imp., Alger, 9.
# 4  0.039216  Laurent (J. A.) (miniature) , rue Nicaise, no. 487.

# %%
train_verif.loc[:, ("CER post corr",)] = train_verif.apply(
        lambda line: local_cer(ref=line["Ground Truth"], pred=line["Predictions"]),
        axis=1)
train_verif.head()
# Out:
#                      book  page  \
# 0     Cambon_almgene_1841   330
# 1            Bottin1_1827    37
# 2            Bottin1_1837    80
# 3       DidotBottin_1861a   424
# 4  Favre_et_Duchesne_1798   700
#
#                                           Ground Truth  \
# 0                        Petit, nég. f. St Martin, 13.
# 1           Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2          Cave générale des hospices, Ne-N. -Dame, 2.
# 3             Moreau (H. ), avoc. cour imp., Alger, 9.
# 4  Jaurent (J. A.) (miniature) , rue Nicaise, no. 487.
#
#                                                                                             NER Ground Truth  \
# 0                        <PER>Petit</PER>, <ACT>nég.</ACT> <LOC>f. St Martin</LOC>, <CARDINAL>13</CARDINAL>.
# 1           <PER>Balizeaux (Mad.)</PER>, <ACT>lingère</ACT>, <LOC>S.-Honuré</LOC>, <CARDINAL>169</CARDINAL>.
# 2                     <PER>Cave générale des hospices</PER>, <LOC>Ne-N. -Dame</LOC>, <CARDINAL>2</CARDINAL>.
# 3             <PER>Moreau (H. )</PER>, <ACT>avoc. cour imp.</ACT>, <LOC>Alger</LOC>, <CARDINAL>9</CARDINAL>.
# 4  <PER>Jaurent (J. A.)</PER> <ACT>(miniature)</ACT> , <LOC>rue Nicaise</LOC>, no. <CARDINAL>487</CARDINAL>.
#
#                                                  Sample  \
# 0                         Felit, neg. f. St Martin, 13.
# 1            Balizeaux (Mad.), lingère, S.-Honoré, 169.
# 2            Cave générale des hospices, Ne-N. Dame, 2.
# 3               Moreau (H.), avoc. cour imp., Alger, 9.
# 4  Laurent (J. A.) (miniature)\n, rue Nicaise, no. 487.
#
#                                                                                                   NER Sample  \
# 0                        <PER>Felit</PER>, <ACT>neg.</ACT> <LOC>f. St Martin</LOC>, <CARDINAL>13</CARDINAL>.
# 1           <PER>Balizeaux (Mad.)</PER>, <ACT>lingère</ACT>, <LOC>S.-Honoré</LOC>, <CARDINAL>169</CARDINAL>.
# 2                      <PER>Cave générale des hospices</PER>, <LOC>Ne-N. Dame</LOC>, <CARDINAL>2</CARDINAL>.
# 3              <PER>Moreau (H.)</PER>, <ACT>avoc. cour imp.</ACT>, <LOC>Alger</LOC>, <CARDINAL>9</CARDINAL>.
# 4  <PER>Laurent (J. A.)</PER> <ACT>(miniature)</ACT>
# , <LOC>rue Nicaise</LOC>, no. <CARDINAL>487</CARDINAL>.
#
#    has_valid_ner_xml  ref_len  errors  insertions  substitutions  deletions  \
# 0               True       29       3           0              3          0
# 1               True       42       1           0              1          0
# 2               True       43       1           1              0          0
# 3               True       40       1           1              0          0
# 4               True       51       2           0              2          0
#
#         CER                                          Predictions  \
# 0  0.103448                        Petit, nég. f. St Martin, 13.
# 1  0.023810           Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2  0.023256          Cave générale des hospices, Ne-N. -Dame, 2.
# 3  0.025000              Moreau (H.), avoc. cour imp., Alger, 9.
# 4  0.039216  Laurent (J. A.) (miniature) , rue Nicaise, no. 487.
#
#    CER post corr
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.025000
# 4       0.019608

# %%
import numpy as np

# %%
train_verif.loc[:, ("same",)] = pd.Series(np.isclose(train_verif["CER post corr"], train_verif["CER"]))
train_verif.loc[:, ("better",)] = train_verif["CER post corr"] < train_verif["CER"]
train_verif.loc[:, ("worse",)] = train_verif["CER post corr"] > train_verif["CER"]
train_verif.head()
# Out:
#                      book  page  \
# 0     Cambon_almgene_1841   330
# 1            Bottin1_1827    37
# 2            Bottin1_1837    80
# 3       DidotBottin_1861a   424
# 4  Favre_et_Duchesne_1798   700
#
#                                           Ground Truth  \
# 0                        Petit, nég. f. St Martin, 13.
# 1           Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2          Cave générale des hospices, Ne-N. -Dame, 2.
# 3             Moreau (H. ), avoc. cour imp., Alger, 9.
# 4  Jaurent (J. A.) (miniature) , rue Nicaise, no. 487.
#
#                                                                                             NER Ground Truth  \
# 0                        <PER>Petit</PER>, <ACT>nég.</ACT> <LOC>f. St Martin</LOC>, <CARDINAL>13</CARDINAL>.
# 1           <PER>Balizeaux (Mad.)</PER>, <ACT>lingère</ACT>, <LOC>S.-Honuré</LOC>, <CARDINAL>169</CARDINAL>.
# 2                     <PER>Cave générale des hospices</PER>, <LOC>Ne-N. -Dame</LOC>, <CARDINAL>2</CARDINAL>.
# 3             <PER>Moreau (H. )</PER>, <ACT>avoc. cour imp.</ACT>, <LOC>Alger</LOC>, <CARDINAL>9</CARDINAL>.
# 4  <PER>Jaurent (J. A.)</PER> <ACT>(miniature)</ACT> , <LOC>rue Nicaise</LOC>, no. <CARDINAL>487</CARDINAL>.
#
#                                                  Sample  \
# 0                         Felit, neg. f. St Martin, 13.
# 1            Balizeaux (Mad.), lingère, S.-Honoré, 169.
# 2            Cave générale des hospices, Ne-N. Dame, 2.
# 3               Moreau (H.), avoc. cour imp., Alger, 9.
# 4  Laurent (J. A.) (miniature)\n, rue Nicaise, no. 487.
#
#                                                                                                   NER Sample  \
# 0                        <PER>Felit</PER>, <ACT>neg.</ACT> <LOC>f. St Martin</LOC>, <CARDINAL>13</CARDINAL>.
# 1           <PER>Balizeaux (Mad.)</PER>, <ACT>lingère</ACT>, <LOC>S.-Honoré</LOC>, <CARDINAL>169</CARDINAL>.
# 2                      <PER>Cave générale des hospices</PER>, <LOC>Ne-N. Dame</LOC>, <CARDINAL>2</CARDINAL>.
# 3              <PER>Moreau (H.)</PER>, <ACT>avoc. cour imp.</ACT>, <LOC>Alger</LOC>, <CARDINAL>9</CARDINAL>.
# 4  <PER>Laurent (J. A.)</PER> <ACT>(miniature)</ACT>
# , <LOC>rue Nicaise</LOC>, no. <CARDINAL>487</CARDINAL>.
#
#    has_valid_ner_xml  ref_len  errors  insertions  substitutions  deletions  \
# 0               True       29       3           0              3          0
# 1               True       42       1           0              1          0
# 2               True       43       1           1              0          0
# 3               True       40       1           1              0          0
# 4               True       51       2           0              2          0
#
#         CER                                          Predictions  \
# 0  0.103448                        Petit, nég. f. St Martin, 13.
# 1  0.023810           Balizeaux (Mad.), lingère, S.-Honuré, 169.
# 2  0.023256          Cave générale des hospices, Ne-N. -Dame, 2.
# 3  0.025000              Moreau (H.), avoc. cour imp., Alger, 9.
# 4  0.039216  Laurent (J. A.) (miniature) , rue Nicaise, no. 487.
#
#    CER post corr   same  better  worse
# 0       0.000000  False    True  False
# 1       0.000000  False    True  False
# 2       0.000000  False    True  False
# 3       0.025000   True   False  False
# 4       0.019608  False    True  False

# %%
train_verif.loc[:, ("has_valid_ner_xml", "same", "better", "worse")].sum(axis=0)
# Out:
# has_valid_ner_xml    4212
# same                  578
# better               2828
# worse                 806
# dtype: int64

# %%
(train_verif[train_verif["worse"]]
 .loc[:,("Sample", "Predictions", "Ground Truth", "CER", "CER post corr")]
 .sort_values(by="CER post corr", ascending=False)
 .head(10))
# Out:
#                                                                        Sample  \
# 3493                                                 n\nBouly R. Charentou\n—
# 3159                                        Chaumin, tailleur,\nVictoire, 28.
# 1066                                    Hug, sellerie, r. de l Echiquier. 38.
# 3605                 —17\nDelasalle, jeune,\nLhumpg, FF.\nK.\n\nE. des: Petis
# 1491              —\nBourguignon freres\nA-T-ELDITES, i\n—\n\nR. Notre-Dan\nS
# 232                            Durbec (F.), épicerie. r. Traînée, passage des
# 1287              Brahy , place du Palais-Egalité, - de la Butte-des-Moulins,
# 2628  —\n\nDuflas, rouennerie, 1. Bourg-l'Abbé, pass.\n412\nde lAncre, 34.\n—
# 3668                                Dupont , à la Croix Rouge , au coin de la
# 3310        Hlélène, salaisons,fromages, fruits secs,etc.\nrue Richelieu, 72.
#
#                                                                                                                                                                                                                                                      Predictions  \
# 3493  Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf, Bouly R. Charentouf
# 3159  Chaumin, tailleur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeur, Villeu
# 1066  Hug, sellerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Echiquier, 38lerie, r. de l'Ech
# 3605  Delasalle, jeune, Lhumpg, FF.\nR. des Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Petis Pe
# 1491  Bourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguignon freres), R. Nourguigno
# 232   Durbec (F.), épicerie. r. Trainée, passage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des Cassage des
# 1287  Brahy, place du Palais-Egalité, - de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2 de la Butte-des-Moulins, 2
# 2628  Duflas, rouennerie, r. Bourg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l'Abbé, pass. Coufg-l
# 3668  Dupont, a la Croix Rouge, au coin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin de la Croin
# 3310  Hlélène, salaisons, fruits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits secs, truits se
#
#                                                           Ground Truth  \
# 3493                                          Bouly, R. Charenton, 103
# 3159                                  Chaumin, tailleur, Victoire, 28.
# 1066                              Hug, sellerie, r. de l'Echiquier, 38
# 3605                  Delasalle, jeune , R. Gr. des Petits\nChamps, 11
# 1491            Bourguignon frères, R. Notre-Dame-\ndes-Victoires, 34.
# 232         Durbec (F.), épicerie. r. Trainée, passage des\nChartreux.
# 1287        Brahy, place du Palais-Egalité, - de la Butte-des-Moulins,
# 2628   Duflos, rouennerie, r. Bourg-l'Abbé, pass.\nde l'Ancre, 34. 412
# 3668  Dupont, à la Croix Rouge , au coin de la\nR. du Vieux Colombier.
# 3310  Hélène, salaisons,fromages, fruits secs,etc.\nrue Richelieu, 72.
#
#            CER  CER post corr
# 3493  0.375000       9.541667
# 3159  0.031250       7.000000
# 1066  0.083333       5.944444
# 3605  0.702128       4.574468
# 1491  0.641509       4.000000
# 232   0.210526       3.526316
# 1287  0.017241       3.310345
# 2628  0.225806       3.241935
# 3668  0.380952       3.174603
# 3310  0.015873       3.174603

# %%
# Augment with stats to be ready to train verifier
train_verif.loc[:, ('sample_len', 'corr_errors', 'corr_insertions', 'corr_substitutions', 'corr_deletions')] = train_verif.apply(
        lambda line: pd.Series(
            local_stats(ref=line["Sample"], pred=line["Predictions"]),
            index=['sample_len', 'corr_errors', 'corr_insertions', 'corr_substitutions', 'corr_deletions']), 
        axis=1,
        result_type='expand')
train_verif.sample(4)
# Out:
#                              book  page  \
# 4113                 Bottin1_1827   117
# 876           Cambon_almgene_1841   330
# 3494                La_Tynna_1813   377
# 3137  Duverneuil_et_La_Tynna_1801   260
#
#                                                                        Ground Truth  \
# 4113                                            Desvaux, nouveautés, S.-Honoré, 25.
# 876                                       Petiteau, coif. Croix des Pet. Champs, 9.
# 3494  Thouin (le chevalier), membre de l'in-\nstitut , rue de Seine-St.-Victor, 35.
# 3137                 AUDEBERT , Camp. à gauche par le boulevard, 143. Observatoire.
#
#                                                                                                                          NER Ground Truth  \
# 4113                                            <PER>Desvaux</PER>, <ACT>nouveautés</ACT>, <LOC>S.-Honoré</LOC>, <CARDINAL>25</CARDINAL>.
# 876                                       <PER>Petiteau</PER>, <ACT>coif.</ACT> <LOC>Croix des Pet. Champs</LOC>, <CARDINAL>9</CARDINAL>.
# 3494  <PER>Thouin (le chevalier)</PER>, <ACT>membre de l'in-\nstitut</ACT> , <LOC>rue de Seine-St.-Victor</LOC>, <CARDINAL>35</CARDINAL>.
# 3137                 <PER>AUDEBERT</PER> , <LOC>Camp. à gauche par le boulevard</LOC>, <CARDINAL>143</CARDINAL>. <LOC>Observatoire</LOC>.
#
#                                                                            Sample  \
# 4113                                          Desvaux, noureautes, S.-Honoré, 27.
# 876                                    Petiteau, coIf. Croix des Fet. Champs, 9..
# 3494  Thouin (le chevalier), membre de lin-\nstitut .rue de Seine-St.-Victor, 55.
# 3137                AUDEBERT, Camp. à gauche par le boulevard, 143. Observatoire.
#
#                                                                                                                             NER Sample  \
# 4113                                         <PER>Desvaux</PER>, <ACT>noureautes</ACT>, <LOC>S.-Honoré</LOC>, <CARDINAL>27</CARDINAL>.
# 876                                   <PER>Petiteau</PER>, <ACT>coIf.</ACT> <LOC>Croix des Fet. Champs</LOC>, <CARDINAL>9</CARDINAL>..
# 3494  <PER>Thouin (le chevalier)</PER>, <ACT>membre de lin-
# stitut</ACT> .<LOC>rue de Seine-St.-Victor</LOC>, <CARDINAL>55</CARDINAL>.
# 3137               <PER>AUDEBERT</PER>, <LOC>Camp. à gauche par le boulevard</LOC>, <CARDINAL>143</CARDINAL>. <LOC>Observatoire</LOC>.
#
#       has_valid_ner_xml  ref_len  errors  insertions  ...  \
# 4113               True       35       3           0  ...
# 876                True       41       3           0  ...
# 3494               True       76       4           2  ...
# 3137               True       62       1           1  ...
#
#                                                                        Predictions  \
# 4113                                           Desvaux, noureautes, S.-Honoré, 27.
# 876                                      Petiteau, coif. Croix des Pet. Champs, 9.
# 3494  Thouin (le chevalier), mémbre de lin-\nstitut . rue de Seine-St.-Victor, 55.
# 3137                                             AUDEBERT, camp. à gauche pardire.
#
#       CER post corr   same better  worse  sample_len  corr_errors  \
# 4113       0.085714   True  False  False          35            0
# 876        0.000000  False   True  False          42            3
# 3494       0.052632   True  False  False          74            2
# 3137       0.483871  False  False   True          61           29
#
#       corr_insertions  corr_substitutions  corr_deletions
# 4113                0                   0               0
# 876                 1                   2               0
# 3494                0                   1               1
# 3137               28                   1               0
#
# [4 rows x 23 columns]

# %%
train_verif.to_pickle("train_verif.pkl")

# %%
# !ls -lh train_verif.pkl
# Out:
# -rw-r--r-- 1 jchazalo lrde 2,1M 29 mai   22:28 train_verif.pkl
